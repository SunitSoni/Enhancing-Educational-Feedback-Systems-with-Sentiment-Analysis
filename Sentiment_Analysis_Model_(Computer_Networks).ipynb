# %% [markdown]
# <a href="https://colab.research.google.com/github/SunitSoni/Enhancing-Educational-Feedback-Systems-with-Sentiment-Analysis/blob/main/Sentiment_Analysis_Model_(Computer_Networks).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Importing Dataset

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
dataset = pd.read_csv('feedback-nlp.csv')
dataset.head(1)
# Out:
#                         Computer Networks (Feedback)  \
# 0  The sessions were fine, but there was a lack o...
#
#   Computer Networks (Satisfaction)  \
# 0                          Neutral
#
#                          Machine Learning (Feedback)  \
# 0  It was an average experience overall; the facu...
#
#   Machine Learning (Satisfaction)  \
# 0                         Neutral
#
#                          Operating System (Feedback)  \
# 0  The faculty did not engage the class effective...
#
#   Operating System (Satisfaction)  \
# 0                        Negative
#
#      Computer Organization & Architecture (Feedback)  \
# 0  The teaching style was acceptable, but the cou...
#
#   Computer Organization & Architecture (Satisfaction)
# 0                                            Neutral

# %%
dataset.shape
# Out:
# (2000, 8)

# %% [markdown]
# ## Computer Networks (Feedback)

# %%
df_CN = dataset[['Computer Networks (Feedback)', 'Computer Networks (Satisfaction)']]
df_CN.head()
# Out:
#                         Computer Networks (Feedback)  \
# 0  The sessions were fine, but there was a lack o...
# 1  The course was very well-structured and the fa...
# 2  The faculty did not engage the class effective...
# 3  The faculty did not engage the class effective...
# 4  The course was decent but could use more examp...
#
#   Computer Networks (Satisfaction)
# 0                          Neutral
# 1                         Positive
# 2                         Negative
# 3                         Negative
# 4                          Neutral

# %%
# Encoding Categorical Target: Computer Networks (Satisfaction)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_CN['Computer Networks (Satisfaction)'] = le.fit_transform(df_CN['Computer Networks (Satisfaction)'])
# Out:
# <ipython-input-6-e1f365e0e78d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_CN['Computer Networks (Satisfaction)'] = le.fit_transform(df_CN['Computer Networks (Satisfaction)'])

# %%
df_CN.head()
# Out:
#                         Computer Networks (Feedback)  \
# 0  The sessions were fine, but there was a lack o...
# 1  The course was very well-structured and the fa...
# 2  The faculty did not engage the class effective...
# 3  The faculty did not engage the class effective...
# 4  The course was decent but could use more examp...
#
#    Computer Networks (Satisfaction)
# 0                                 1
# 1                                 2
# 2                                 0
# 3                                 0
# 4                                 1

# %% [markdown]
# ### Data Preprocessing

# %%
import re # regular expression import
import nltk

nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

all_stopwords = stopwords.words('english') # storing stop word in all_stopwords
all_stopwords.remove('not')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
corpus=[] # store students data post data cleaning

for i in range(0, 2000): # runs row by row to clean every data we have in our dataset
  review = re.sub('[^a-zA-Z]', ' ', df_CN['Computer Networks (Feedback)'][i]) # dropping all special symbols
  review = review.lower() # converting to lower case
  review = review.split()
  review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
  review = ' '.join(review)
  corpus.append(review)

# %%
# corpus

# %% [markdown]
# ### Data Transformation

# %%
# convert cleaned data into bag of words
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 8) # we are taking top 'max_features' most frequent tokens and dropping the left overs

# %%
df_CN.head(2)
# Out:
#                         Computer Networks (Feedback)  \
# 0  The sessions were fine, but there was a lack o...
# 1  The course was very well-structured and the fa...
#
#    Computer Networks (Satisfaction)
# 0                                 1
# 1                                 2

# %%
X = cv.fit_transform(corpus).toarray()
y = df_CN.iloc[:, -1].values

# %%
X.shape
# Out:
# (2000, 8)

# %%
y.shape
# Out:
# (2000,)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# Encoding 'Computer Networks (Satisfaction)'
ct = ColumnTransformer(transformers = [('encoder', OneHotEncoder(sparse_output=False), [0])], remainder = 'passthrough')
y = np.array(ct.fit_transform(y.reshape(-1,1)))

# %% [markdown]
# ### Splitting Dataset

# %%
#%60 for train, %28 for val, %12 for test
from sklearn.model_selection import train_test_split
X_train,X_val,Y_train,Y_val = train_test_split(X, y, random_state=42, test_size= 0.4)

#Split test and val dataset.
X_val,X_test,Y_val,Y_test = train_test_split(X_val,Y_val,random_state = 42,test_size = 0.3)
print(f"{X_train.shape}, {X_test.shape}, {X_val.shape}")

# # Dimension Reduction
# from sklearn.decomposition import PCA
# pca = PCA(n_components = 5)
# X_train = pca.fit_transform(X_train)
# X_val = pca.fit_transform(X_val)
# X_test = pca.transform(X_test)
# Out:
# (1200, 8), (240, 8), (560, 8)

# %% [markdown]
# ### ANN Definition

# %%
import tensorflow as tf
from keras.layers import Dense, Dropout
from keras.models import Sequential
def build_model():
    model = Sequential()
    #Input layer
    model.add(Dense(32, activation = "relu", kernel_initializer = "he_normal",input_dim = len(X_train[0])))
    #Hidden layer 1
    model.add(Dense(64, activation = "relu", kernel_initializer = "he_normal"))
    model.add(Dropout(0.3))
    #Hidden layer 2
    model.add(Dense(128, activation = "relu", kernel_initializer = "he_normal"))
    model.add(Dropout(0.3))
    #Hidden layer 3
    model.add(Dense(64, activation = "relu", kernel_initializer = "he_normal"))
    model.add(Dropout(0.3))
    #Hidden layer 4
    model.add(Dense(32, activation = "relu", kernel_initializer = "he_normal"))
    model.add(Dropout(0.3))
    #Output layer
    model.add(Dense(3, activation = "softmax", kernel_initializer = "he_normal"))
    return model

# %%
model = build_model()
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │             288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 3)                   │              99 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 21,155 (82.64 KB)
#  Trainable params: 21,155 (82.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0001),
             loss = "categorical_crossentropy", metrics = ["accuracy"])

history = model.fit(X_train, Y_train, batch_size = 64, epochs = 200,
                         validation_data=(X_val,Y_val), callbacks = tf.keras.callbacks.EarlyStopping(monitor="val_loss",patience=3))
# Out:
# Epoch 1/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.3234 - loss: 2.2356 - val_accuracy: 0.5071 - val_loss: 1.0615
# Epoch 2/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3649 - loss: 1.8763 - val_accuracy: 0.4357 - val_loss: 1.0526
# Epoch 3/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3522 - loss: 1.9181 - val_accuracy: 0.3661 - val_loss: 1.0477
# Epoch 4/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3494 - loss: 1.6708 - val_accuracy: 0.3661 - val_loss: 1.0397
# Epoch 5/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3478 - loss: 1.7220 - val_accuracy: 0.3661 - val_loss: 1.0308
# Epoch 6/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3568 - loss: 1.6380 - val_accuracy: 0.3661 - val_loss: 1.0165
# Epoch 7/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3906 - loss: 1.4484 - val_accuracy: 0.3661 - val_loss: 1.0039
# Epoch 8/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3808 - loss: 1.4291 - val_accuracy: 0.3661 - val_loss: 0.9892
# Epoch 9/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3876 - loss: 1.4045 - val_accuracy: 0.4196 - val_loss: 0.9785
# Epoch 10/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3678 - loss: 1.4595 - val_accuracy: 0.4196 - val_loss: 0.9624
# Epoch 11/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4295 - loss: 1.2651 - val_accuracy: 0.4196 - val_loss: 0.9480
# Epoch 12/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4487 - loss: 1.2321 - val_accuracy: 0.4196 - val_loss: 0.9349
# Epoch 13/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4007 - loss: 1.2885 - val_accuracy: 0.4196 - val_loss: 0.9271
# Epoch 14/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4037 - loss: 1.2643 - val_accuracy: 0.4196 - val_loss: 0.9201
# Epoch 15/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4343 - loss: 1.1619 - val_accuracy: 0.4196 - val_loss: 0.9164
# Epoch 16/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4323 - loss: 1.1378 - val_accuracy: 0.4196 - val_loss: 0.9094
# Epoch 17/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4290 - loss: 1.1794 - val_accuracy: 0.4196 - val_loss: 0.9013
# Epoch 18/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4927 - loss: 1.0875 - val_accuracy: 0.4839 - val_loss: 0.8950
# Epoch 19/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4569 - loss: 1.1197 - val_accuracy: 0.5607 - val_loss: 0.8890
# Epoch 20/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4325 - loss: 1.1177 - val_accuracy: 0.6286 - val_loss: 0.8783
# Epoch 21/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4578 - loss: 1.0806 - val_accuracy: 0.6982 - val_loss: 0.8729
# Epoch 22/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4751 - loss: 1.0705 - val_accuracy: 0.7821 - val_loss: 0.8649
# Epoch 23/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4587 - loss: 1.0669 - val_accuracy: 0.7821 - val_loss: 0.8603
# Epoch 24/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4756 - loss: 1.0893 - val_accuracy: 0.7821 - val_loss: 0.8533
# Epoch 25/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4719 - loss: 1.0664 - val_accuracy: 0.7821 - val_loss: 0.8455
# Epoch 26/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5085 - loss: 1.0112 - val_accuracy: 0.7821 - val_loss: 0.8366
# Epoch 27/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5191 - loss: 0.9744 - val_accuracy: 0.7821 - val_loss: 0.8235
# Epoch 28/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5468 - loss: 0.9615 - val_accuracy: 0.7821 - val_loss: 0.8078
# Epoch 29/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5189 - loss: 0.9872 - val_accuracy: 0.7821 - val_loss: 0.7930
# Epoch 30/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5576 - loss: 0.9111 - val_accuracy: 0.7821 - val_loss: 0.7807
# Epoch 31/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5686 - loss: 0.9168 - val_accuracy: 0.8500 - val_loss: 0.7674
# Epoch 32/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5502 - loss: 0.9145 - val_accuracy: 0.8500 - val_loss: 0.7516
# Epoch 33/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5596 - loss: 0.8998 - val_accuracy: 0.8500 - val_loss: 0.7381
# Epoch 34/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5727 - loss: 0.8859 - val_accuracy: 0.8500 - val_loss: 0.7282
# Epoch 35/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6038 - loss: 0.8497 - val_accuracy: 0.9232 - val_loss: 0.7163
# Epoch 36/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5617 - loss: 0.8939 - val_accuracy: 0.9232 - val_loss: 0.7013
# Epoch 37/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5851 - loss: 0.8572 - val_accuracy: 0.9232 - val_loss: 0.6887
# Epoch 38/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6065 - loss: 0.8419 - val_accuracy: 0.9232 - val_loss: 0.6769
# Epoch 39/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5783 - loss: 0.8703 - val_accuracy: 0.9232 - val_loss: 0.6668
# Epoch 40/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5967 - loss: 0.8541 - val_accuracy: 0.9232 - val_loss: 0.6579
# Epoch 41/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6201 - loss: 0.8085 - val_accuracy: 0.9232 - val_loss: 0.6456
# Epoch 42/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5968 - loss: 0.8011 - val_accuracy: 0.9232 - val_loss: 0.6336
# Epoch 43/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6217 - loss: 0.7972 - val_accuracy: 0.9232 - val_loss: 0.6215
# Epoch 44/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6699 - loss: 0.7588 - val_accuracy: 0.9232 - val_loss: 0.6086
# Epoch 45/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6295 - loss: 0.7664 - val_accuracy: 0.9232 - val_loss: 0.5968
# Epoch 46/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6444 - loss: 0.7570 - val_accuracy: 0.9232 - val_loss: 0.5856
# Epoch 47/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6653 - loss: 0.7176 - val_accuracy: 0.9232 - val_loss: 0.5744
# Epoch 48/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6507 - loss: 0.7433 - val_accuracy: 0.9232 - val_loss: 0.5637
# Epoch 49/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6472 - loss: 0.7329 - val_accuracy: 0.9232 - val_loss: 0.5539
# Epoch 50/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6518 - loss: 0.7228 - val_accuracy: 0.9232 - val_loss: 0.5422
# Epoch 51/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7185 - loss: 0.6446 - val_accuracy: 0.9232 - val_loss: 0.5288
# Epoch 52/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6895 - loss: 0.6624 - val_accuracy: 0.9232 - val_loss: 0.5170
# Epoch 53/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7204 - loss: 0.6432 - val_accuracy: 0.9232 - val_loss: 0.5065
# Epoch 54/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7022 - loss: 0.6580 - val_accuracy: 0.9232 - val_loss: 0.4934
# Epoch 55/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6831 - loss: 0.6845 - val_accuracy: 0.9232 - val_loss: 0.4819
# Epoch 56/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6838 - loss: 0.6798 - val_accuracy: 0.9232 - val_loss: 0.4702
# Epoch 57/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6987 - loss: 0.6629 - val_accuracy: 0.9232 - val_loss: 0.4590
# Epoch 58/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7387 - loss: 0.6096 - val_accuracy: 0.9232 - val_loss: 0.4483
# Epoch 59/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7251 - loss: 0.6070 - val_accuracy: 0.9232 - val_loss: 0.4354
# Epoch 60/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7313 - loss: 0.6150 - val_accuracy: 0.9232 - val_loss: 0.4213
# Epoch 61/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7004 - loss: 0.6207 - val_accuracy: 0.9232 - val_loss: 0.4097
# Epoch 62/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7419 - loss: 0.5761 - val_accuracy: 0.9232 - val_loss: 0.4004
# Epoch 63/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7563 - loss: 0.5663 - val_accuracy: 0.9232 - val_loss: 0.3887
# Epoch 64/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7719 - loss: 0.5459 - val_accuracy: 0.9232 - val_loss: 0.3752
# Epoch 65/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7468 - loss: 0.5854 - val_accuracy: 0.9232 - val_loss: 0.3617
# Epoch 66/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7716 - loss: 0.5121 - val_accuracy: 0.9232 - val_loss: 0.3492
# Epoch 67/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7468 - loss: 0.5491 - val_accuracy: 0.9232 - val_loss: 0.3363
# Epoch 68/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7869 - loss: 0.5008 - val_accuracy: 0.9232 - val_loss: 0.3240
# Epoch 69/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7876 - loss: 0.5013 - val_accuracy: 0.9232 - val_loss: 0.3124
# Epoch 70/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8018 - loss: 0.4574 - val_accuracy: 0.9232 - val_loss: 0.3021
# Epoch 71/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7911 - loss: 0.4700 - val_accuracy: 0.9232 - val_loss: 0.2915
# Epoch 72/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8064 - loss: 0.4737 - val_accuracy: 0.9232 - val_loss: 0.2818
# Epoch 73/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7939 - loss: 0.4755 - val_accuracy: 0.9232 - val_loss: 0.2721
# Epoch 74/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8052 - loss: 0.4391 - val_accuracy: 0.9232 - val_loss: 0.2630
# Epoch 75/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8022 - loss: 0.4454 - val_accuracy: 0.9232 - val_loss: 0.2555
# Epoch 76/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8271 - loss: 0.4384 - val_accuracy: 0.9232 - val_loss: 0.2473
# Epoch 77/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8527 - loss: 0.3827 - val_accuracy: 0.9232 - val_loss: 0.2399
# Epoch 78/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8111 - loss: 0.4249 - val_accuracy: 0.9232 - val_loss: 0.2323
# Epoch 79/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8489 - loss: 0.3773 - val_accuracy: 0.9232 - val_loss: 0.2259
# Epoch 80/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8377 - loss: 0.3775 - val_accuracy: 0.9232 - val_loss: 0.2206
# Epoch 81/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8464 - loss: 0.3808 - val_accuracy: 0.9232 - val_loss: 0.2154
# Epoch 82/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8364 - loss: 0.3947 - val_accuracy: 0.9232 - val_loss: 0.2106
# Epoch 83/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8424 - loss: 0.3721 - val_accuracy: 0.9232 - val_loss: 0.2060
# Epoch 84/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8386 - loss: 0.3780 - val_accuracy: 0.9232 - val_loss: 0.2018
# Epoch 85/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8434 - loss: 0.3688 - val_accuracy: 0.9232 - val_loss: 0.1972
# Epoch 86/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8595 - loss: 0.3427 - val_accuracy: 0.9232 - val_loss: 0.1912
# Epoch 87/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8521 - loss: 0.3412 - val_accuracy: 0.9232 - val_loss: 0.1858
# Epoch 88/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8667 - loss: 0.3249 - val_accuracy: 0.9232 - val_loss: 0.1804
# Epoch 89/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8683 - loss: 0.3218 - val_accuracy: 0.9232 - val_loss: 0.1771
# Epoch 90/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8609 - loss: 0.3416 - val_accuracy: 0.9232 - val_loss: 0.1739
# Epoch 91/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8481 - loss: 0.3330 - val_accuracy: 0.9232 - val_loss: 0.1710
# Epoch 92/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8595 - loss: 0.3008 - val_accuracy: 0.9232 - val_loss: 0.1680
# Epoch 93/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8841 - loss: 0.3045 - val_accuracy: 0.9232 - val_loss: 0.1636
# Epoch 94/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8950 - loss: 0.2795 - val_accuracy: 0.9232 - val_loss: 0.1597
# Epoch 95/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8861 - loss: 0.2667 - val_accuracy: 0.9232 - val_loss: 0.1573
# Epoch 96/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8679 - loss: 0.2948 - val_accuracy: 0.9232 - val_loss: 0.1541
# Epoch 97/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8616 - loss: 0.2889 - val_accuracy: 0.9232 - val_loss: 0.1505
# Epoch 98/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8899 - loss: 0.2653 - val_accuracy: 0.9232 - val_loss: 0.1461
# Epoch 99/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8816 - loss: 0.2696 - val_accuracy: 0.9232 - val_loss: 0.1437
# Epoch 100/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8944 - loss: 0.2624 - val_accuracy: 0.9232 - val_loss: 0.1428
# Epoch 101/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8982 - loss: 0.2424 - val_accuracy: 0.9232 - val_loss: 0.1408
# Epoch 102/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8896 - loss: 0.2563 - val_accuracy: 0.9232 - val_loss: 0.1392
# Epoch 103/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8949 - loss: 0.2491 - val_accuracy: 0.9232 - val_loss: 0.1384
# Epoch 104/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9112 - loss: 0.2181 - val_accuracy: 0.9232 - val_loss: 0.1361
# Epoch 105/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9005 - loss: 0.2427 - val_accuracy: 0.9232 - val_loss: 0.1336
# Epoch 106/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8889 - loss: 0.2420 - val_accuracy: 0.9232 - val_loss: 0.1316
# Epoch 107/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9109 - loss: 0.2341 - val_accuracy: 0.9232 - val_loss: 0.1307
# Epoch 108/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8962 - loss: 0.2366 - val_accuracy: 0.9232 - val_loss: 0.1305
# Epoch 109/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9110 - loss: 0.2176 - val_accuracy: 0.9232 - val_loss: 0.1313
# Epoch 110/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9031 - loss: 0.2181 - val_accuracy: 0.9232 - val_loss: 0.1301
# Epoch 111/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9205 - loss: 0.2030 - val_accuracy: 0.9232 - val_loss: 0.1284
# Epoch 112/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8937 - loss: 0.2320 - val_accuracy: 0.9232 - val_loss: 0.1282
# Epoch 113/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8841 - loss: 0.2499 - val_accuracy: 0.9232 - val_loss: 0.1274
# Epoch 114/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8924 - loss: 0.2309 - val_accuracy: 0.9232 - val_loss: 0.1265
# Epoch 115/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9095 - loss: 0.2108 - val_accuracy: 0.9232 - val_loss: 0.1247
# Epoch 116/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9016 - loss: 0.2191 - val_accuracy: 0.9232 - val_loss: 0.1235
# Epoch 117/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9021 - loss: 0.2192 - val_accuracy: 0.9232 - val_loss: 0.1229
# Epoch 118/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9047 - loss: 0.2101 - val_accuracy: 0.9232 - val_loss: 0.1226
# Epoch 119/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9262 - loss: 0.1862 - val_accuracy: 0.9232 - val_loss: 0.1215
# Epoch 120/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9104 - loss: 0.1842 - val_accuracy: 0.9232 - val_loss: 0.1201
# Epoch 121/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9175 - loss: 0.1832 - val_accuracy: 0.9232 - val_loss: 0.1193
# Epoch 122/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9317 - loss: 0.1669 - val_accuracy: 0.9232 - val_loss: 0.1181
# Epoch 123/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9296 - loss: 0.1746 - val_accuracy: 0.9232 - val_loss: 0.1170
# Epoch 124/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9194 - loss: 0.1741 - val_accuracy: 0.9232 - val_loss: 0.1162
# Epoch 125/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9156 - loss: 0.1807 - val_accuracy: 0.9232 - val_loss: 0.1160
# Epoch 126/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9236 - loss: 0.1738 - val_accuracy: 0.9232 - val_loss: 0.1164
# Epoch 127/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9002 - loss: 0.1993 - val_accuracy: 0.9232 - val_loss: 0.1173
# Epoch 128/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9132 - loss: 0.1774 - val_accuracy: 0.9232 - val_loss: 0.1167

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (12,5))

epochs = len(history.history["accuracy"])
plt.subplot(1,2,1)
plt.title("Train Accuracy and Val Accuracy")
plt.plot(range(epochs),history.history["accuracy"])
plt.plot(range(epochs),history.history["val_accuracy"])
plt.legend(["accuracy","val_accuracy"])

plt.subplot(1,2,2)
plt.title("Train Loss and Val Loss")
plt.plot(range(epochs),history.history["loss"])
plt.plot(range(epochs),history.history["val_loss"])
plt.legend(["loss","val_loss"])

# %% [markdown]
# ## Model Performance

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, average_precision_score

# Step 1: Evaluate the model on the test dataset
X_test_reshaped = X_test.reshape(-1, X_test.shape[1])
loss, accuracy = model.evaluate(X_test_reshaped, Y_test, verbose=0)

print(f"Model Loss: {loss:.4f}")
print(f"Model Accuracy: {accuracy:.4f}")

# Step 2: Generate predictions
Y_pred = model.predict(X_test_reshaped)
Y_pred_classes = Y_pred.argmax(axis=1)
Y_test_classes = Y_test.argmax(axis=1)

# Step 3: Generate a detailed classification report
print('\n------------------------------------------------\n')
report = classification_report(Y_test_classes, Y_pred_classes, target_names=['Class 0', 'Class 1', 'Class 2'])
print("\nClassification Report:\n", report)
# Out:
# Model Loss: 0.1183
# Model Accuracy: 0.9250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# ------------------------------------------------
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      Class 0       0.81      1.00      0.89        76
#      Class 1       1.00      0.79      0.88        85
#      Class 2       1.00      1.00      1.00        79
#
#     accuracy                           0.93       240
#    macro avg       0.94      0.93      0.93       240
# weighted avg       0.94      0.93      0.92       240
